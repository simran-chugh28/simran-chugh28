# %% [markdown]
# ## Importing the Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading the Data

# %%
df = pd.read_csv('Loan_default.csv')

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### 1. Data Discovery

# %%
df.head()
# Out:
#        LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  I38PQUQS96   56   85994       50587          520              80
# 1  HPSK72WA7R   69   50432      124440          458              15
# 2  C1OZ6DPJ8Y   46   84208      129188          451              26
# 3  V2KKSFM3UN   32   31713       44799          743               0
# 4  EY08JDHTZP   60   20437        9139          633               8
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0               4         15.23        36      0.44   Bachelor's
# 1               1          4.81        60      0.68     Master's
# 2               3         21.17        24      0.31     Master's
# 3               3          7.07        24      0.23  High School
# 4               4          6.51        48      0.73   Bachelor's
#
#   EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0      Full-time      Divorced         Yes           Yes       Other
# ...

# %%
df.tail()
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 255342  8C6S86ESGC   19   37979      210682          541             109
# 255343  98R4KDHNND   32   51953      189899          511              14
# 255344  XQK1UUUNGP   56   84820      208294          597              70
# 255345  JAO28CPL4H   42   85109       60575          809              40
# 255346  ZTH91CGL0B   62   22418       18481          636             113
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 255342               4         14.11        12      0.85   Bachelor's
# 255343               2         11.55        24      0.21  High School
# 255344               3          5.29        60      0.50  High School
# 255345               1         20.90        48      0.44  High School
# 255346               2          6.73        12      0.48   Bachelor's
#
#        EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255347 entries, 0 to 255346
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   LoanID          255347 non-null  object
#  1   Age             255347 non-null  int64
#  2   Income          255347 non-null  int64
#  3   LoanAmount      255347 non-null  int64
#  4   CreditScore     255347 non-null  int64
#  5   MonthsEmployed  255347 non-null  int64
#  6   NumCreditLines  255347 non-null  int64
#  7   InterestRate    255347 non-null  float64
#  8   LoanTerm        255347 non-null  int64
#  9   DTIRatio        255347 non-null  float64
#  10  Education       255347 non-null  object
#  11  EmploymentType  255347 non-null  object
#  12  MaritalStatus   255347 non-null  object
#  13  HasMortgage     255347 non-null  object
#  14  HasDependents   255347 non-null  object
#  15  LoanPurpose     255347 non-null  object
# ...

# %%
df.describe()
# Out:
#                  Age         Income     LoanAmount    CreditScore  \
# count  255347.000000  255347.000000  255347.000000  255347.000000
# mean       43.498306   82499.304597  127578.865512     574.264346
# std        14.990258   38963.013729   70840.706142     158.903867
# min        18.000000   15000.000000    5000.000000     300.000000
# 25%        31.000000   48825.500000   66156.000000     437.000000
# 50%        43.000000   82466.000000  127556.000000     574.000000
# 75%        56.000000  116219.000000  188985.000000     712.000000
# max        69.000000  149999.000000  249999.000000     849.000000
#
#        MonthsEmployed  NumCreditLines   InterestRate       LoanTerm  \
# count   255347.000000   255347.000000  255347.000000  255347.000000
# mean        59.541976        2.501036      13.492773      36.025894
# std         34.643376        1.117018       6.636443      16.969330
# min          0.000000        1.000000       2.000000      12.000000
# ...

# %%
df.columns.values
# Out:
# array(['LoanID', 'Age', 'Income', 'LoanAmount', 'CreditScore',
#        'MonthsEmployed', 'NumCreditLines', 'InterestRate', 'LoanTerm',
#        'DTIRatio', 'Education', 'EmploymentType', 'MaritalStatus',
#        'HasMortgage', 'HasDependents', 'LoanPurpose', 'HasCoSigner',
#        'Default'], dtype=object)

# %%
df.shape
# Out:
# (255347, 18)

# %% [markdown]
# #### Checking for Null Values

# %%
df.isnull().sum()
# Out:
# LoanID            0
# Age               0
# Income            0
# LoanAmount        0
# CreditScore       0
# MonthsEmployed    0
# NumCreditLines    0
# InterestRate      0
# LoanTerm          0
# DTIRatio          0
# Education         0
# EmploymentType    0
# MaritalStatus     0
# HasMortgage       0
# HasDependents     0
# LoanPurpose       0
# HasCoSigner       0
# Default           0
# dtype: int64

# %% [markdown]
# #### Checking for Duplicate Data

# %%
df.duplicated().sum()
# Out:
# 0

# %%
categorical_variables=['Education', 'EmploymentType', 'MaritalStatus', 'HasMortgage', 
                       'HasDependents', 'LoanPurpose','NumCreditLines', 'HasCoSigner', 'Default']


numerical_variables=['Age', 'Income', 'LoanAmount', 'CreditScore', 
                     'MonthsEmployed', 'InterestRate', 'LoanTerm', 'DTIRatio',]

# %% [markdown]
# #### Checking for Outliers

# %%
plt.figure(figsize=(20, 10))
ind=1
for  variable in (numerical_variables):
    plt.subplot(3, 3, ind)
    sns.boxplot(x=df[variable],color="blue")
    plt.title(variable)
    ind+=1
    plt.xlabel('')
plt.tight_layout()
plt.savefig('Boxplot in Data Discovery.png')
plt.show()

# %%
for variable in categorical_variables:
    print(df[variable].value_counts())
    print("-"*50)
# Out:
# Education
# Bachelor's     64366
# High School    63903
# Master's       63541
# PhD            63537
# Name: count, dtype: int64
# --------------------------------------------------
# EmploymentType
# Part-time        64161
# Unemployed       63824
# Self-employed    63706
# Full-time        63656
# Name: count, dtype: int64
# --------------------------------------------------
# MaritalStatus
# Married     85302
# Divorced    85033
# Single      85012
# Name: count, dtype: int64
# --------------------------------------------------
# HasMortgage
# Yes    127677
# No     127670
# Name: count, dtype: int64
# --------------------------------------------------
# HasDependents
# Yes    127742
# No     127605
# Name: count, dtype: int64
# --------------------------------------------------
# LoanPurpose
# Business     51298
# Home         51286
# Education    51005
# Other        50914
# Auto         50844
# Name: count, dtype: int64
# --------------------------------------------------
# ...

# %% [markdown]
# ### 2. Data Tranformation

# %% [markdown]
# #### Adding New Columns to the Dataframe

# %%
df['IncomePerCreditLine'] = df['Income'] / df['NumCreditLines']
df['LoanAmountToIncome'] = df['LoanAmount'] / df['Income']

# %% [markdown]
# #### Replacing categorical columns containing 'Yes' and 'No' values to Numerical

# %%
df['HasMortgage_n'] = df['HasMortgage'].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
df['HasDependents_n'] = df['HasDependents'].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
df['HasCoSigner_n'] = df['HasCoSigner'].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
df = df.drop(columns=['HasMortgage', 'HasDependents', 'HasCoSigner'])

# %% [markdown]
# ### 3. Data Validation

# %%
df.head()
# Out:
#        LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  I38PQUQS96   56   85994       50587          520              80
# 1  HPSK72WA7R   69   50432      124440          458              15
# 2  C1OZ6DPJ8Y   46   84208      129188          451              26
# 3  V2KKSFM3UN   32   31713       44799          743               0
# 4  EY08JDHTZP   60   20437        9139          633               8
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0               4         15.23        36      0.44   Bachelor's
# 1               1          4.81        60      0.68     Master's
# 2               3         21.17        24      0.31     Master's
# 3               3          7.07        24      0.23  High School
# 4               4          6.51        48      0.73   Bachelor's
#
#   EmploymentType MaritalStatus LoanPurpose  Default  IncomePerCreditLine  \
# 0      Full-time      Divorced       Other        0         21498.500000
# ...

# %%
df.tail()
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 255342  8C6S86ESGC   19   37979      210682          541             109
# 255343  98R4KDHNND   32   51953      189899          511              14
# 255344  XQK1UUUNGP   56   84820      208294          597              70
# 255345  JAO28CPL4H   42   85109       60575          809              40
# 255346  ZTH91CGL0B   62   22418       18481          636             113
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 255342               4         14.11        12      0.85   Bachelor's
# 255343               2         11.55        24      0.21  High School
# 255344               3          5.29        60      0.50  High School
# 255345               1         20.90        48      0.44  High School
# 255346               2          6.73        12      0.48   Bachelor's
#
#        EmploymentType MaritalStatus LoanPurpose  Default  IncomePerCreditLine  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255347 entries, 0 to 255346
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   LoanID               255347 non-null  object
#  1   Age                  255347 non-null  int64
#  2   Income               255347 non-null  int64
#  3   LoanAmount           255347 non-null  int64
#  4   CreditScore          255347 non-null  int64
#  5   MonthsEmployed       255347 non-null  int64
#  6   NumCreditLines       255347 non-null  int64
#  7   InterestRate         255347 non-null  float64
#  8   LoanTerm             255347 non-null  int64
#  9   DTIRatio             255347 non-null  float64
#  10  Education            255347 non-null  object
#  11  EmploymentType       255347 non-null  object
#  12  MaritalStatus        255347 non-null  object
#  13  LoanPurpose          255347 non-null  object
#  14  Default              255347 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  Age         Income     LoanAmount    CreditScore  \
# count  255347.000000  255347.000000  255347.000000  255347.000000
# mean       43.498306   82499.304597  127578.865512     574.264346
# std        14.990258   38963.013729   70840.706142     158.903867
# min        18.000000   15000.000000    5000.000000     300.000000
# 25%        31.000000   48825.500000   66156.000000     437.000000
# 50%        43.000000   82466.000000  127556.000000     574.000000
# 75%        56.000000  116219.000000  188985.000000     712.000000
# max        69.000000  149999.000000  249999.000000     849.000000
#
#        MonthsEmployed  NumCreditLines   InterestRate       LoanTerm  \
# count   255347.000000   255347.000000  255347.000000  255347.000000
# mean        59.541976        2.501036      13.492773      36.025894
# std         34.643376        1.117018       6.636443      16.969330
# min          0.000000        1.000000       2.000000      12.000000
# ...

# %%
df.columns.values
# Out:
# array(['LoanID', 'Age', 'Income', 'LoanAmount', 'CreditScore',
#        'MonthsEmployed', 'NumCreditLines', 'InterestRate', 'LoanTerm',
#        'DTIRatio', 'Education', 'EmploymentType', 'MaritalStatus',
#        'LoanPurpose', 'Default', 'IncomePerCreditLine',
#        'LoanAmountToIncome', 'HasMortgage_n', 'HasDependents_n',
#        'HasCoSigner_n'], dtype=object)

# %%
df.shape
# Out:
# (255347, 20)

# %% [markdown]
# #### Checking for Null Values

# %%
df.isnull().sum()
# Out:
# LoanID                 0
# Age                    0
# Income                 0
# LoanAmount             0
# CreditScore            0
# MonthsEmployed         0
# NumCreditLines         0
# InterestRate           0
# LoanTerm               0
# DTIRatio               0
# Education              0
# EmploymentType         0
# MaritalStatus          0
# LoanPurpose            0
# Default                0
# IncomePerCreditLine    0
# LoanAmountToIncome     0
# HasMortgage_n          0
# HasDependents_n        0
# HasCoSigner_n          0
# dtype: int64

# %% [markdown]
# #### Checking for Duplicate Data

# %%
df.duplicated().sum()
# Out:
# 0

# %%
categorical_variables=['Education', 'EmploymentType', 'MaritalStatus', 'HasMortgage_n', 
                       'HasDependents_n', 'LoanPurpose','NumCreditLines', 'HasCoSigner_n', 'Default']


numerical_variables=['Age', 'Income', 'LoanAmount', 'CreditScore', 
                     'MonthsEmployed', 'InterestRate', 'LoanTerm', 
                     'DTIRatio', 'IncomePerCreditLine', 'LoanAmountToIncome']

# %% [markdown]
# #### Checking for Outliers

# %%
plt.figure(figsize=(20, 10))
ind=1
for  variable in (numerical_variables):
    plt.subplot(4, 3, ind)
    sns.boxplot(x=df[variable],color="blue")
    plt.title(variable)
    ind+=1
    plt.xlabel('')
plt.tight_layout()
plt.savefig('Boxplot in Data Validation.png')
plt.show()

# %%
for variable in categorical_variables:
    print(df[variable].value_counts())
    print("-"*50)
# Out:
# Education
# Bachelor's     64366
# High School    63903
# Master's       63541
# PhD            63537
# Name: count, dtype: int64
# --------------------------------------------------
# EmploymentType
# Part-time        64161
# Unemployed       63824
# Self-employed    63706
# Full-time        63656
# Name: count, dtype: int64
# --------------------------------------------------
# MaritalStatus
# Married     85302
# Divorced    85033
# Single      85012
# Name: count, dtype: int64
# --------------------------------------------------
# HasMortgage_n
# 1    127677
# 0    127670
# Name: count, dtype: int64
# --------------------------------------------------
# HasDependents_n
# 1    127742
# 0    127605
# Name: count, dtype: int64
# --------------------------------------------------
# LoanPurpose
# Business     51298
# Home         51286
# Education    51005
# Other        50914
# Auto         50844
# Name: count, dtype: int64
# --------------------------------------------------
# ...

# %% [markdown]
# ### 4. Data Publishing

# %%
df.to_excel('Loan_default_cleaned.xlsx', index=False)
